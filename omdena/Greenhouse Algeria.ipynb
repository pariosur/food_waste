# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv('Production System.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipykernel_17673/3395754623.py in <module>
# ----> 1 df = pd.read_csv('Production System.csv')
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     315                     stacklevel=find_stack_level(inspect.currentframe()),
#     316                 )
# --> 317             return func(*args, **kwargs)
#     318
#     319         return wrapper
#
# ...

# %%
df
# Out:
#   Country Name Target Product  Unit Yield   User  Visible Cultivar Type  \
# 0      Algeria  Fruiting body      120000  10888        2   Hybrid seed
# 1      Algeria         Fruits      120000  10888        2   Hybrid seed
# 2      Algeria         Fruits      120000  10889        2   Hybrid seed
# 3      Algeria  Fruiting body         120  10887        2   Hybrid seed
# 4      Algeria         Fruits         120  10890        2   Hybrid seed
#
#   Culture Media   Unit   Crop Type        Record Environment  Density  \
# 0          Soil  kg/ha  Vegetables  Farm field (small-scale)    27000
# 1          Soil  kg/ha  Vegetables  Farm field (small-scale)    27000
# 2          Soil  kg/ha  Vegetables  Farm field (small-scale)    25000
# 3          Soil   t/ha  Vegetables  Farm field (small-scale)    27000
# 4          Soil   t/ha  Vegetables  Farm field (small-scale)    27000
#
#   Production Method         Date Created      F1 Production System
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country Name        5 non-null      object
#  1   Target Product      5 non-null      object
#  2   Unit Yield          5 non-null      int64
#  3   User                5 non-null      int64
#  4   Visible             5 non-null      int64
#  5   Cultivar Type       5 non-null      object
#  6   Culture Media       5 non-null      object
#  7   Unit                5 non-null      object
#  8   Crop Type           5 non-null      object
#  9   Record Environment  5 non-null      object
#  10  Density             5 non-null      int64
#  11  Production Method   5 non-null      object
#  12  Date Created        5 non-null      object
#  13  F1                  5 non-null      int64
#  14  Production System   5 non-null      object
# dtypes: int64(5), object(10)
# ...
